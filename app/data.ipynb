# %%
import pandas as pd

# %%
data = pd.read_csv('Dados.csv')

# %%
data
# Out:
#      Verificador                                              Texto  Mês  \
# 0           Real  As U.S. budget fight looms, Republicans flip t...   12
# 1           Real  U.S. military to accept transgender recruits o...   12
# 2           Real  Senior U.S. Republican senator: 'Let Mr. Muell...   12
# 3           Real  FBI Russia probe helped by Australian diplomat...   12
# 4           Real  Trump wants Postal Service to charge 'much mor...   12
# ...          ...                                                ...  ...
# 3995       Falso   Watch Legendary Reporter Ted Koppel Tell Hann...    3
# 3996       Falso   Someone Just Showed What Trump Was Doing At H...    3
# 3997       Falso   Trump Accidentally Makes Democrats Look Great...    3
# 3998       Falso   Kremlin Threatens Trump: Stop Leaking Like A ...    3
# 3999       Falso   Republicans Turn On Trump, Throw Him Under Th...    3
#
#       Popularidade
# 0           191494
# 1            87239
# 2            86922
# 3            78428
# 4            75781
# ...            ...
# 3995          1177
# 3996           983
# 3997           948
# 3998           928
# 3999         47793
#
# [4000 rows x 4 columns]

# %%
input = 'trump'
random = data[data['Texto'].str.contains(input)].sample(30)

# %%
random
# Out:
#      Verificador                                              Texto  Mês  \
# 3662       Falso   Americans TORCH Hypocrite GOP Lawmaker For Us...    4
# 2380       Falso   Racist GOP Rep. Steve King Goes BALLISTIC Ove...    9
# 2617       Falso   Sean Hannity Swears He’ll ‘Stop Petty Politic...    8
# 2140       Falso   Hawaiians Had The Perfect Signs To Infuriate ...   11
# 1424        Real  Whirlpool's washer war is balancing act for Tr...   10
# 2068       Falso   Sean Hannity Gets Wrecked For Yelling At Time...   11
# 3992       Falso   The Internet Goes For Newt Gingrich’s Throat ...    3
# 1472        Real  U.S. visas to six Muslim nations drop after Su...    9
# 2934       Falso   Paul Manafort’s Daughters Say Their Father Is...    7
# 2720       Falso   Insane Racist Fired For Death Threats Against...    7
# 2981       Falso   Nikki Haley Gets Crucified On Twitter After B...    6
# 3382       Falso   WATCH: Melania HUMILIATES Trump On World Stag...    5
# 1591        Real  Despite undiplomatic discourse, Trump's dance ...    9
# 2748       Falso   Trump Gets Wrecked After Confirming Secret CI...    7
# 3257       Falso   Trump: I Won’t Stop Tweeting Even Though The ...    6
# 2003       Falso   Trump Is So Obsessed He Even Has Obama’s Name...   12
# 3099       Falso   Obama Shows Trump What A Classy Father’s Day ...    6
# 3462       Falso   Internet SLAMS Trump Over Mother’s Day Women’...    5
# 3328       Falso   More And More Local Governments Are Passing R...    5
# 884         Real  Trump's opponents race to the courthouse to th...   11
# 3153       Falso   Snowflake Trump Demands An Apology From The M...    6
# 3960       Falso   The New York Times Just FIRED BACK At Trump W...    3
# 3786       Falso   Librarians Just HUMILIATED Ivanka Trump For B...    4
# 3171       Falso   Trump Tweets About His Impeachment Chances In...    6
# 3989       Falso   BREAKING: Devin Nunes Is Now The Subject Of A...    3
# 2932       Falso   Watch Confused Trump Wander Aimlessly Away Fr...    7
# 3097       Falso   WATCH: Media Critics Tear Megyn Kelly Apart F...    6
# 3944       Falso   BREAKING: Michael Flynn Agrees To Testify On ...    3
# 2120       Falso   Trump Jr. Goes Full Dumba** On Twitter By Pro...   11
# 2983       Falso   Time Magazine Tells Trump To Stop Displaying ...    6
#
#       Popularidade
# 3662         13052
# 2380           898
# 2617          1313
# 2140          8645
# 1424          1022
# 2068          3306
# 3992          1942
# 1472           966
# 2934          1000
# 2720          3058
# 2981          8159
# 3382          1119
# 1591           854
# 2748          1868
# 3257          1729
# 2003         12745
# 3099          1407
# 3462           954
# 3328          4910
# 884           2122
# 3153           907
# 3960          3783
# 3786          1531
# 3171         10462
# 3989          2765
# 2932          1031
# 3097          1420
# 3944          1100
# 2120         15225
# 2983          7685

# %%
import plotly.express as px
value_counts = random['Verificador'].value_counts()
fig = px.pie(names=value_counts.index, values=value_counts.values,  title='Quantidade de notícias:')
fig.show()

# %%
fake = random[random['Verificador'] == 'Falso']

# %%
counts = fake['Mês'].value_counts()

# %%
counts
# Out:
# 6     7
# 7     4
# 3     4
# 11    3
# 5     3
# 4     2
# 12    1
# 9     1
# 8     1
# Name: Mês, dtype: int64

# %%
figu = px.bar(fake, x=counts.index, y=counts.values, title="Distribuição de notícias falsas",  labels=dict(x="Mês", y="Quantidade de notícias falsas"))

# %%
figu.show()

# %%
top = fake.sort_values(by=['Popularidade'],ascending=False ).head(5)

# %%
rank = top[['Texto', 'Verificador']]

# %%
rank
# Out:
#                                                   Texto Verificador
# 2120   Trump Jr. Goes Full Dumba** On Twitter By Pro...       Falso
# 3662   Americans TORCH Hypocrite GOP Lawmaker For Us...       Falso
# 2003   Trump Is So Obsessed He Even Has Obama’s Name...       Falso
# 3171   Trump Tweets About His Impeachment Chances In...       Falso
# 2140   Hawaiians Had The Perfect Signs To Infuriate ...       Falso
